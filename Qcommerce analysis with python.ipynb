# %% [markdown]
# # 🚀Working on Real Project using Python

# %% [markdown]
# ### Qcommerce Analysis using Python
# This is a synthetic Quick Commerce (Q-Commerce) dataset simulating real-world order data from platforms like Blinkit, Zepto, Swiggy Instamart, and others.
#
# It contains rich order-level features such as city, category, delivery time, ratings, discounts, and revenue, making it ideal for practicing data cleaning, EDA, visualization, dashboard building, and extracting business insights.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Vishwas Reddy\Downloads\quick_commerce_data_raw.csv")

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85          NaN        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [1000000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                        52000
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                 35000
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %% [markdown]
# # Remove Null Values from City

# %%
df=df.dropna(subset="City")

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85          NaN        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                33228
# Product_Category               0
# Payment_Method                 0
# Customer_Rating            44575
# Discount_Applied               0
# Delivery_Partner_Rating    98694
# dtype: int64

# %% [markdown]
# # Items_Count has null values,since it is count of items we can replace it with mode

# %%
df["Items_Count"].mode()
# Out:
# 0    19.0
# Name: Items_Count, dtype: float64

# %%
# replace it with 19
df["Items_Count"].fillna(19,inplace=True)
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\2033620950.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Items_Count"].fillna(19,inplace=True)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\2033620950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Items_Count"].fillna(19,inplace=True)

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
# checking missing values
df.isnull().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                    0
# Product_Category               0
# Payment_Method                 0
# Customer_Rating            44575
# Discount_Applied               0
# Delivery_Partner_Rating    98694
# dtype: int64

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %% [markdown]
# # Replacing Customer_Rating Null Values with Mean/Median

# %%
df["Customer_Rating"]=df.groupby("Company")["Customer_Rating"].transform(lambda x:x.fillna(x.mean()))
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\2923737493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Customer_Rating"]=df.groupby("Company")["Customer_Rating"].transform(lambda x:x.fillna(x.mean()))

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                    0
# Product_Category               0
# Payment_Method                 0
# Customer_Rating                0
# Discount_Applied               0
# Delivery_Partner_Rating    98694
# dtype: int64

# %% [markdown]
# # Replace Delivery_Partner_Rating NAN values with Mean/Median

# %%
df["Delivery_Partner_Rating"]=df.groupby("Delivery_Time_Min")["Delivery_Partner_Rating"].transform(lambda y:y.fillna(y.mean()))
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3088175750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Delivery_Partner_Rating"]=df.groupby("Delivery_Time_Min")["Delivery_Partner_Rating"].transform(lambda y:y.fillna(y.mean()))

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID                    0
# Company                     0
# City                        0
# Customer_Age                0
# Order_Value                 0
# Delivery_Time_Min           0
# Distance_Km                 0
# Items_Count                 0
# Product_Category            0
# Payment_Method              0
# Customer_Rating             0
# Discount_Applied            0
# Delivery_Partner_Rating    76
# dtype: int64

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
df["Delivery_Partner_Rating"]=df["Delivery_Partner_Rating"].fillna(df["Delivery_Partner_Rating"].mean())
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\444464365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Delivery_Partner_Rating"]=df["Delivery_Partner_Rating"].fillna(df["Delivery_Partner_Rating"].mean())

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Company                    0
# City                       0
# Customer_Age               0
# Order_Value                0
# Delivery_Time_Min          0
# Distance_Km                0
# Items_Count                0
# Product_Category           0
# Payment_Method             0
# Customer_Rating            0
# Discount_Applied           0
# Delivery_Partner_Rating    0
# dtype: int64

# %% [markdown]
# # check with the outliers

# %%
plt.figure()
df.boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(17,5))
df.boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(17,5))
df.drop(columns="Order_ID").boxplot()
# Out:
# <Axes: >

# %%
Q1= df['Order_Value'].quantile(0.25)
Q3= df['Order_Value'].quantile(0.99)
print(Q1)
print(Q3)
# Out:
# 287.992575
# 1635.093015

# %%
IQR= Q3-Q1
IQR
# Out:
# np.float64(1347.10044)

# %%
lower_bound= Q1-(1.5*IQR)
print(lower_bound)
# Out:
# -1732.6580849999998

# %%
upper_bound=Q3+(1.5*IQR)
upper_bound
# Out:
# np.float64(3655.7436749999997)

# %%
df['Order_Value'] = df['Order_Value'].clip(lower= lower_bound,upper = 2500)
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\4252233409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Value'] = df['Order_Value'].clip(lower= lower_bound,upper = 2500)

# %%
plt.figure(figsize = (17,5))

df.drop(columns = ['Order_ID']).boxplot(vert = False, showmeans = True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Order_ID                 948000 non-null  int64
#  1   Company                  948000 non-null  object
#  2   City                     948000 non-null  object
#  3   Customer_Age             948000 non-null  int64
#  4   Order_Value              948000 non-null  float64
#  5   Delivery_Time_Min        948000 non-null  float64
#  6   Distance_Km              948000 non-null  float64
#  7   Items_Count              948000 non-null  float64
#  8   Product_Category         948000 non-null  object
#  9   Payment_Method           948000 non-null  object
#  10  Customer_Rating          948000 non-null  float64
#  11  Discount_Applied         948000 non-null  int64
#  12  Delivery_Partner_Rating  948000 non-null  float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 101.3+ MB

# %%
plt.figure(figsize = (15,3))

df.drop(columns = ['Order_ID']).boxplot(vert = False, showmeans = True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Order_ID                 948000 non-null  int64
#  1   Company                  948000 non-null  object
#  2   City                     948000 non-null  object
#  3   Customer_Age             948000 non-null  int64
#  4   Order_Value              948000 non-null  float64
#  5   Delivery_Time_Min        948000 non-null  float64
#  6   Distance_Km              948000 non-null  float64
#  7   Items_Count              948000 non-null  float64
#  8   Product_Category         948000 non-null  object
#  9   Payment_Method           948000 non-null  object
#  10  Customer_Rating          948000 non-null  float64
#  11  Discount_Applied         948000 non-null  int64
#  12  Delivery_Partner_Rating  948000 non-null  float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 101.3+ MB

# %%
df["Order_ID"]=df["Order_ID"].astype(str)
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\1575728499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Order_ID"]=df["Order_ID"].astype(str)

# %%
df
# Out:
#        Order_ID           Company      City  Customer_Age  Order_Value  \
# 0       1000001  Swiggy Instamart     Noida            46    702.33750
# 1       1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2       1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3       1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4       1000005             Dunzo    Mumbai            44    586.02550
# ...         ...               ...       ...           ...          ...
# 999995  1999996        Big Basket    Mumbai            48     72.33000
# 999996  1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997  1999998          Jio Mart     Noida            29    637.32300
# 999998  1999999             Dunzo      Pune            42   1103.12100
# 999999  2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                  19.182        11.97         12.0                Dairy
# 1                  19.644        12.74         10.0               Snacks
# 2                  16.910         4.85         19.0        Personal Care
# 3                   5.864         6.44          2.0                Dairy
# 4                  12.470         2.45         13.0            Household
# ...                   ...          ...          ...                  ...
# 999995             17.806         3.01         19.0  Fruits & Vegetables
# 999996             18.306        10.51          9.0            Beverages
# 999997             17.590         2.65          6.0            Groceries
# 999998             12.656         7.76         12.0               Snacks
# 999999             17.670         9.45         13.0               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet              2.1                 1
# 1       Cash on Delivery              2.3                 0
# 2       Cash on Delivery              3.3                 0
# 3            Credit Card              5.0                 1
# 4                 Wallet              3.7                 0
# ...                  ...              ...               ...
# 999995            Wallet              4.2                 0
# 999996        Debit Card              4.1                 1
# 999997  Cash on Delivery              3.4                 0
# 999998            Wallet              4.0                 1
# 999999       Credit Card              4.1                 0
#
#         Delivery_Partner_Rating
# 0                           3.2
# 1                           3.2
# 2                           3.8
# 3                           5.0
# 4                           4.8
# ...                         ...
# 999995                      2.8
# 999996                      3.5
# 999997                      4.6
# 999998                      4.5
# 999999                      4.8
#
# [948000 rows x 13 columns]

# %%
import numpy as np
df['Order_Value'] = np.round(df['Order_Value'])

df['Delivery_Time_Min'] = np.round(df['Delivery_Time_Min'])

df['Distance_Km'] = np.round(df['Distance_Km'], 1)

df['Customer_Rating'] = np.round(df['Customer_Rating'])

df['Delivery_Partner_Rating'] = np.round(df['Delivery_Partner_Rating'])
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\968140471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Value'] = np.round(df['Order_Value'])
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\968140471.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Time_Min'] = np.round(df['Delivery_Time_Min'])
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\968140471.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Distance_Km'] = np.round(df['Distance_Km'], 1)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\968140471.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer_Rating'] = np.round(df['Customer_Rating'])
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\968140471.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Partner_Rating'] = np.round(df['Delivery_Partner_Rating'])

# %%
df['Order_Value'] = df['Order_Value'].astype(int)

df['Delivery_Time_Min'] = df['Delivery_Time_Min'].astype(int)

df['Items_Count'] = df['Items_Count'].astype(int)

df['Customer_Rating'] = df['Customer_Rating'].astype(int)

df['Delivery_Partner_Rating'] = df['Delivery_Partner_Rating'].astype(int)
# Out:
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3864826316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Value'] = df['Order_Value'].astype(int)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3864826316.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Time_Min'] = df['Delivery_Time_Min'].astype(int)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3864826316.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Items_Count'] = df['Items_Count'].astype(int)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3864826316.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer_Rating'] = df['Customer_Rating'].astype(int)
# C:\Users\Vishwas Reddy\AppData\Local\Temp\ipykernel_24200\3864826316.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Partner_Rating'] = df['Delivery_Partner_Rating'].astype(int)

# %%
df
# Out:
#        Order_ID           Company      City  Customer_Age  Order_Value  \
# 0       1000001  Swiggy Instamart     Noida            46          702
# 1       1000002  Flipkart Minutes  Amritsar            56         1007
# 2       1000003  Flipkart Minutes    Mumbai            18         1212
# 3       1000004  Swiggy Instamart     Delhi            23         1179
# 4       1000005             Dunzo    Mumbai            44          586
# ...         ...               ...       ...           ...          ...
# 999995  1999996        Big Basket    Mumbai            48           72
# 999996  1999997  Swiggy Instamart    Mumbai            33         1510
# 999997  1999998          Jio Mart     Noida            29          637
# 999998  1999999             Dunzo      Pune            42         1103
# 999999  2000000        Amazon Now   Chennai            19          759
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 0                      19         12.0           12                Dairy
# 1                      20         12.7           10               Snacks
# 2                      17          4.8           19        Personal Care
# 3                       6          6.4            2                Dairy
# 4                      12          2.4           13            Household
# ...                   ...          ...          ...                  ...
# 999995                 18          3.0           19  Fruits & Vegetables
# 999996                 18         10.5            9            Beverages
# 999997                 18          2.6            6            Groceries
# 999998                 13          7.8           12               Snacks
# 999999                 18          9.4           13               Snacks
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 0                 Wallet                2                 1
# 1       Cash on Delivery                2                 0
# 2       Cash on Delivery                3                 0
# 3            Credit Card                5                 1
# 4                 Wallet                4                 0
# ...                  ...              ...               ...
# 999995            Wallet                4                 0
# 999996        Debit Card                4                 1
# 999997  Cash on Delivery                3                 0
# 999998            Wallet                4                 1
# 999999       Credit Card                4                 0
#
#         Delivery_Partner_Rating
# 0                             3
# 1                             3
# 2                             4
# 3                             5
# 4                             5
# ...                         ...
# 999995                        3
# 999996                        4
# 999997                        5
# 999998                        4
# 999999                        5
#
# [948000 rows x 13 columns]

# %%
df.to_csv(r"D:\Qcommerce Analysis\Qcommerce_dataset.csv",index=False)

# %% [markdown]
# # >> Business Questions <<

# %% [markdown]
# ## Q.1) Which quick commerce platform has the highest total revenue?

# %%
Company_revenue=df.groupby('Company')["Order_Value"].sum()

# %%
Company_revenue
# Out:
# Company
# Amazon Now          65892504
# Big Basket          67974762
# Blinkit             72589575
# Dunzo               64070079
# Flipkart Minutes    67058289
# Jio Mart            57160360
# Swiggy Instamart    76532756
# Zepto               70424672
# Name: Order_Value, dtype: int64

# %%
Company_revenue.sort_values(ascending=False)
# Out:
# Company
# Swiggy Instamart    76532756
# Blinkit             72589575
# Zepto               70424672
# Big Basket          67974762
# Flipkart Minutes    67058289
# Amazon Now          65892504
# Dunzo               64070079
# Jio Mart            57160360
# Name: Order_Value, dtype: int64

# %%
Max=Company_revenue.max()
Min=Company_revenue.min()

# %%
plt.figure(figsize = (10,5))

colors = ['green' if val == Max else
          'red' if val == Min else
          'olive'
          for val in Company_revenue          
         ]
Company_revenue.plot( kind = 'bar', color = colors, width = 0.3)
Company_revenue.plot(kind = 'line', color = 'black',marker="*")

plt.xlabel("Quick Commerce Platforms", fontsize = 12)
plt.ylabel("Total Revenue", fontsize = 12)
plt.title("Total Revenue by Quick Commerce Platform")
plt.show()

# %% [markdown]
# ## Q.2) Which platform has the highest average order value (AOV)?

# %%
AOV=df.groupby("Company")["Order_Value"].mean().sort_values(ascending=False)
AOV
# Out:
# Company
# Swiggy Instamart    645.709816
# Blinkit             610.391388
# Zepto               593.804939
# Big Basket          575.652397
# Flipkart Minutes    563.567128
# Amazon Now          557.905154
# Dunzo               540.730530
# Jio Mart            483.238591
# Name: Order_Value, dtype: float64

# %%
x=AOV.index
plt.figure(figsize=(6,6))
plt.pie(AOV,labels=x,shadow=True,autopct="%2.2f%%",textprops ={"fontsize":12,"fontweight":"bold"})
plt.title("Average Order Value by Quick Commerce Platform")
plt.show()

# %% [markdown]
# ## Q.3) How does Customer Rating vary across platforms?

# %%
Customer_rating=  df.groupby(['Company', 'Customer_Rating']).size().unstack(fill_value=0)
Customer_rating
# Out:
# Customer_Rating       1      2      3      4      5
# Company
# Amazon Now        15980  30358  30870  29704  11195
# Big Basket        10144  30351  31027  30918  15643
# Blinkit            1061  25563  25567  36720  30012
# Dunzo             29825  36285  25385  25822   1171
# Flipkart Minutes  12550  30789  31232  30991  13427
# Jio Mart          18516  30519  31088  30095   8068
# Swiggy Instamart   5002  30287  31051  30945  21240
# Zepto              7619  29773  31380  30568  19259

# %%
Customer_rating.plot(kind = 'bar')
plt.xlabel("Company Name")
plt.ylabel("Number of Ratings")
plt.title("Distribution of Customer Ratings Across Platforms")
plt.legend(title = 'Customer Rating', bbox_to_anchor = (1, 0.7), loc = 'upper left')
plt.xticks(rotation = 30, ha = 'right')
plt.show()

# %% [markdown]
# ## Q.4) Does 'Delivery Time' affects the 'Delivery Partner Ratings'?

# %%
x = df.groupby('Delivery_Time_Min')['Delivery_Partner_Rating'].mean()
x
# Out:
# Delivery_Time_Min
# 5     3.804022
# 6     3.798591
# 7     3.805865
# 8     3.803796
# 9     3.804402
# 10    3.801602
# 11    3.799979
# 12    3.798861
# 13    3.795765
# 14    3.797314
# 15    3.798016
# 16    3.799100
# 17    3.802359
# 18    3.801807
# 19    3.809682
# 20    3.804834
# 21    3.802936
# 22    3.804560
# 23    3.794302
# 24    3.791276
# 25    3.800332
# 26    3.795161
# 27    3.799749
# 28    3.796468
# 29    3.792997
# 30    3.788623
# 31    3.807241
# 32    3.789289
# 33    3.781402
# 34    3.770451
# 35    3.779251
# 36    3.752239
# 37    3.732039
# 38    3.741307
# 39    3.799097
# 40    3.737589
# Name: Delivery_Partner_Rating, dtype: float64

# %%
x.plot(marker = '*')
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Average Delivery Partner Rating")
plt.title("Impact of Delivery Time on Delivery Partner Rating")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q.5) What is the most popular Product Category on Swiggy Instamart, for the people of age between 30-40, in Mumbai?

# %%
y=df[(df['Company'] == 'Swiggy Instamart') & ((df['Customer_Age'] > 30) & (df['Customer_Age'] < 40)) & (df["City"] == 'Mumbai')]
y
# Out:
#        Order_ID           Company    City  Customer_Age  Order_Value  \
# 536     1000537  Swiggy Instamart  Mumbai            38         1157
# 909     1000910  Swiggy Instamart  Mumbai            32          926
# 1203    1001204  Swiggy Instamart  Mumbai            37          234
# 2918    1002919  Swiggy Instamart  Mumbai            31          423
# 4251    1004252  Swiggy Instamart  Mumbai            36           50
# ...         ...               ...     ...           ...          ...
# 997610  1997611  Swiggy Instamart  Mumbai            37          448
# 999242  1999243  Swiggy Instamart  Mumbai            32          747
# 999258  1999259  Swiggy Instamart  Mumbai            35           50
# 999680  1999681  Swiggy Instamart  Mumbai            39          375
# 999996  1999997  Swiggy Instamart  Mumbai            33         1510
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 536                    14          5.7           18            Beverages
# 909                    20         14.2            3                Dairy
# 1203                   19          7.6            6                Dairy
# 2918                   15          4.0           10                Dairy
# 4251                   15          2.2           12                Dairy
# ...                   ...          ...          ...                  ...
# 997610                 19         14.0           17  Fruits & Vegetables
# 999242                 13          2.4           12            Household
# 999258                 18          7.6            4        Personal Care
# 999680                 19          8.7            6            Household
# 999996                 18         10.5            9            Beverages
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 536     Cash on Delivery                4                 1
# 909                  UPI                2                 0
# 1203          Debit Card                5                 0
# 2918    Cash on Delivery                2                 0
# 4251         Credit Card                3                 0
# ...                  ...              ...               ...
# 997610  Cash on Delivery                5                 0
# 999242               UPI                5                 1
# 999258        Debit Card                5                 0
# 999680            Wallet                2                 0
# 999996        Debit Card                4                 1
#
#         Delivery_Partner_Rating
# 536                           4
# 909                           5
# 1203                          4
# 2918                          3
# 4251                          3
# ...                         ...
# 997610                        5
# 999242                        5
# 999258                        5
# 999680                        4
# 999996                        4
#
# [2104 rows x 13 columns]

# %%
d=y['Product_Category'].value_counts()
d
# Out:
# Product_Category
# Dairy                  332
# Household              311
# Groceries              310
# Fruits & Vegetables    307
# Snacks                 303
# Personal Care          272
# Beverages              269
# Name: count, dtype: int64

# %%
d.plot(marker="*",color="purple",markersize=15)
d.plot(kind="line",color="black")
# colors=("red" if val == Max else "Blue" if val == Mi=  
plt.xlabel("Product_Categories")
plt.ylabel("Count 0f Product categories")
plt.title("Most Popular Product Category in given criteria")
plt.tight_layout()
plt.xticks(rotation=30,ha='right')
plt.show()
